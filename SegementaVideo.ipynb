# %%
import numpy as np
import cv2
import os
from datetime import datetime
import time

nome_arquivo = ".{}data{}bandeja.mp4".format( os.sep,os.sep, os.sep)

porcent = 50

def define_dimensao(porcent, frame):

    height, width, depth = last_frame.shape
    imgScale = (porcent*10.)/width
    newX, newY = last_frame.shape[1]*imgScale, last_frame.shape[0]*imgScale
    return newX, newY

def juntar_imagens(img1, img2):
    new_img = np.hstack((img1, img2))
    return new_img

def normaliza_borra(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (25, 25), 0)
    return gray

# %%
num_frames_std=0
last_status=None
last_move=0
current_frame=last_move
print(nome_arquivo, os.path.isfile(nome_arquivo))
print('.{}data{}{}{}'.format(os.sep,os.sep,1,'.png'))
# Out:
# ./data/bandeja.mp4 True
# ./data/1.png

# %%
if os.path.isfile(nome_arquivo):
    cap = cv2.VideoCapture(nome_arquivo)

    ret, last_frame = cap.read()
    print('isOpened ',cap.isOpened())
    if last_frame is None:
        print('last_frame ',last_frame)
        exit()

    newX, newY = define_dimensao(porcent, last_frame)
    last_frame = cv2.resize(last_frame, (int(newX), int(newY)))
    last_frame_norm = normaliza_borra(last_frame)

    frame_parados = 0
    status_motion = "STOP"
    print('video ',cap.isOpened())
    while(cap.isOpened()):
        ret, frame = cap.read()

        if frame is None:
            break
            
        current_frame=current_frame+1
        frame = cv2.resize(frame, (int(newX), int(newY)))
        newFrame = normaliza_borra(frame)

        a = cv2.absdiff(last_frame_norm, newFrame)        
            
        media_de_cor = a.mean()
        if media_de_cor < 0.25:
            status_motion = "STOP"            
        else:
            status_motion = "MOTION"
            
        if(last_status!=status_motion):
            if((current_frame-last_move)>10):
                print(current_frame,last_move,(current_frame-last_move))
                num_frames_std= num_frames_std+1
                cv2.imwrite('.{}data{}{}{}'.format(os.sep,os.sep,num_frames_std,'.png'),frame)
            last_status= status_motion
            last_move=current_frame
            
            
        print("current_frame",current_frame," status_motion ",status_motion)    


        cv2.putText(frame, "Room Status: {}; Number frames stopped: {}".format(status_motion,num_frames_std), (10, 20),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        cv2.putText(frame, datetime.now().strftime("%A %d %B %Y %I:%M:%S%p"),(10, frame.shape[0] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.35, (0, 255, 0), 1)

        motion_detection = juntar_imagens(newFrame, a)
        cv2.imshow('original', frame)
        cv2.imshow('motion detection', motion_detection)

        if cv2.waitKey(33) >= 0:
            break

        last_frame_norm = newFrame

    cap.release()
    cv2.destroyAllWindows()
else:
    print("video não existe")
# Out:
# isOpened  True
# video  True
# current_frame 1  status_motion  STOP
# current_frame 2  status_motion  STOP
# current_frame 3  status_motion  STOP
# current_frame 4  status_motion  STOP
# current_frame 5  status_motion  STOP
# current_frame 6  status_motion  STOP
# current_frame 7  status_motion  STOP
# current_frame 8  status_motion  STOP
# current_frame 9  status_motion  STOP
# current_frame 10  status_motion  STOP
# current_frame 11  status_motion  STOP
# current_frame 12  status_motion  STOP
# current_frame 13  status_motion  STOP
# current_frame 14  status_motion  STOP
# current_frame 15  status_motion  STOP
# current_frame 16  status_motion  STOP
# current_frame 17  status_motion  STOP
# current_frame 18  status_motion  STOP
# current_frame 19  status_motion  STOP
# current_frame 20  status_motion  STOP
# current_frame 21  status_motion  STOP
# current_frame 22  status_motion  STOP
# current_frame 23  status_motion  STOP
# current_frame 24  status_motion  STOP
# current_frame 25  status_motion  STOP
# current_frame 26  status_motion  STOP
# current_frame 27  status_motion  STOP
# current_frame 28  status_motion  STOP
# current_frame 29  status_motion  STOP
# current_frame 30  status_motion  STOP
# current_frame 31  status_motion  STOP
# current_frame 32  status_motion  STOP
# current_frame 33  status_motion  STOP
# current_frame 34  status_motion  STOP
# current_frame 35  status_motion  STOP
# current_frame 36  status_motion  STOP
# current_frame 37  status_motion  STOP
# current_frame 38  status_motion  STOP
# 39 1 38
# current_frame 39  status_motion  MOTION
# current_frame 40  status_motion  MOTION
# current_frame 41  status_motion  MOTION
# current_frame 42  status_motion  MOTION
# current_frame 43  status_motion  MOTION
# current_frame 44  status_motion  MOTION
# current_frame 45  status_motion  MOTION
# current_frame 46  status_motion  MOTION
# current_frame 47  status_motion  MOTION
# current_frame 48  status_motion  MOTION
# current_frame 49  status_motion  MOTION
# current_frame 50  status_motion  MOTION
# current_frame 51  status_motion  MOTION
# current_frame 52  status_motion  MOTION
# current_frame 53  status_motion  MOTION
# current_frame 54  status_motion  MOTION
# current_frame 55  status_motion  MOTION
# current_frame 56  status_motion  MOTION
# current_frame 57  status_motion  MOTION
# current_frame 58  status_motion  MOTION
# current_frame 59  status_motion  MOTION
# current_frame 60  status_motion  MOTION
# current_frame 61  status_motion  MOTION
# current_frame 62  status_motion  MOTION
# current_frame 63  status_motion  MOTION
# current_frame 64  status_motion  MOTION
# current_frame 65  status_motion  MOTION
# current_frame 66  status_motion  MOTION
# current_frame 67  status_motion  MOTION
# current_frame 68  status_motion  MOTION
# current_frame 69  status_motion  MOTION
# current_frame 70  status_motion  MOTION
# current_frame 71  status_motion  MOTION
# current_frame 72  status_motion  MOTION
# current_frame 73  status_motion  MOTION
# current_frame 74  status_motion  MOTION
# current_frame 75  status_motion  MOTION
# current_frame 76  status_motion  MOTION
# current_frame 77  status_motion  MOTION
# current_frame 78  status_motion  MOTION
# current_frame 79  status_motion  MOTION
# current_frame 80  status_motion  MOTION
# current_frame 81  status_motion  MOTION
# current_frame 82  status_motion  MOTION
# current_frame 83  status_motion  MOTION
# current_frame 84  status_motion  MOTION
# current_frame 85  status_motion  MOTION
# 86 39 47
# current_frame 86  status_motion  STOP
# current_frame 87  status_motion  STOP
# current_frame 88  status_motion  MOTION
# current_frame 89  status_motion  MOTION
# current_frame 90  status_motion  MOTION
# current_frame 91  status_motion  MOTION
# current_frame 92  status_motion  MOTION
# current_frame 93  status_motion  MOTION
# current_frame 94  status_motion  MOTION
# current_frame 95  status_motion  MOTION
# current_frame 96  status_motion  MOTION
# current_frame 97  status_motion  MOTION
# current_frame 98  status_motion  MOTION
# current_frame 99  status_motion  MOTION
# current_frame 100  status_motion  MOTION
# current_frame 101  status_motion  MOTION
# current_frame 102  status_motion  MOTION
# current_frame 103  status_motion  MOTION
# current_frame 104  status_motion  MOTION
# current_frame 105  status_motion  MOTION
# current_frame 106  status_motion  MOTION
# current_frame 107  status_motion  MOTION
# current_frame 108  status_motion  MOTION
# current_frame 109  status_motion  MOTION
# current_frame 110  status_motion  MOTION
# current_frame 111  status_motion  MOTION
# 112 88 24
# current_frame 112  status_motion  STOP
# current_frame 113  status_motion  MOTION
# current_frame 114  status_motion  MOTION
# current_frame 115  status_motion  STOP
# current_frame 116  status_motion  MOTION
# current_frame 117  status_motion  MOTION
# current_frame 118  status_motion  MOTION
# current_frame 119  status_motion  MOTION
# current_frame 120  status_motion  MOTION
# current_frame 121  status_motion  MOTION
# current_frame 122  status_motion  MOTION
# current_frame 123  status_motion  MOTION
# current_frame 124  status_motion  MOTION
# current_frame 125  status_motion  MOTION
# current_frame 126  status_motion  STOP
# current_frame 127  status_motion  STOP
# current_frame 128  status_motion  STOP
# current_frame 129  status_motion  STOP
# current_frame 130  status_motion  MOTION
# current_frame 131  status_motion  MOTION
# current_frame 132  status_motion  MOTION
# current_frame 133  status_motion  MOTION
# current_frame 134  status_motion  MOTION
# current_frame 135  status_motion  MOTION
# current_frame 136  status_motion  MOTION
# current_frame 137  status_motion  MOTION
# current_frame 138  status_motion  MOTION
# current_frame 139  status_motion  MOTION
# current_frame 140  status_motion  MOTION
# current_frame 141  status_motion  MOTION
# current_frame 142  status_motion  MOTION
# current_frame 143  status_motion  MOTION
# current_frame 144  status_motion  MOTION
# current_frame 145  status_motion  MOTION
# current_frame 146  status_motion  MOTION
# current_frame 147  status_motion  MOTION
# current_frame 148  status_motion  MOTION
# current_frame 149  status_motion  MOTION
# current_frame 150  status_motion  MOTION
# current_frame 151  status_motion  MOTION
# 152 130 22
# current_frame 152  status_motion  STOP
# current_frame 153  status_motion  STOP
# current_frame 154  status_motion  STOP
# current_frame 155  status_motion  STOP
# current_frame 156  status_motion  STOP
# current_frame 157  status_motion  STOP
# current_frame 158  status_motion  MOTION
# current_frame 159  status_motion  MOTION
# current_frame 160  status_motion  MOTION
# current_frame 161  status_motion  MOTION
# current_frame 162  status_motion  MOTION
# current_frame 163  status_motion  MOTION
# current_frame 164  status_motion  MOTION
# current_frame 165  status_motion  MOTION
# current_frame 166  status_motion  MOTION
# current_frame 167  status_motion  MOTION
# current_frame 168  status_motion  MOTION
# current_frame 169  status_motion  MOTION
# current_frame 170  status_motion  MOTION
# current_frame 171  status_motion  MOTION
# current_frame 172  status_motion  MOTION
# current_frame 173  status_motion  MOTION
# current_frame 174  status_motion  MOTION
# current_frame 175  status_motion  MOTION
# current_frame 176  status_motion  MOTION
# current_frame 177  status_motion  MOTION
# current_frame 178  status_motion  MOTION
# current_frame 179  status_motion  MOTION
# current_frame 180  status_motion  MOTION
# current_frame 181  status_motion  MOTION
# current_frame 182  status_motion  MOTION
# current_frame 183  status_motion  MOTION
# current_frame 184  status_motion  MOTION
# current_frame 185  status_motion  MOTION
# current_frame 186  status_motion  MOTION
# current_frame 187  status_motion  MOTION
# current_frame 188  status_motion  MOTION
# current_frame 189  status_motion  MOTION
# 190 158 32
# current_frame 190  status_motion  STOP
# current_frame 191  status_motion  STOP
# current_frame 192  status_motion  STOP
# current_frame 193  status_motion  STOP
# current_frame 194  status_motion  STOP
# current_frame 195  status_motion  STOP
# current_frame 196  status_motion  STOP
# current_frame 197  status_motion  STOP
# current_frame 198  status_motion  STOP
# current_frame 199  status_motion  STOP
# current_frame 200  status_motion  STOP
# current_frame 201  status_motion  STOP
# current_frame 202  status_motion  STOP
# current_frame 203  status_motion  STOP
# current_frame 204  status_motion  STOP
# current_frame 205  status_motion  STOP
# current_frame 206  status_motion  STOP
# current_frame 207  status_motion  STOP
# current_frame 208  status_motion  STOP
# current_frame 209  status_motion  STOP
# current_frame 210  status_motion  STOP
# 211 190 21
# current_frame 211  status_motion  MOTION
# current_frame 212  status_motion  MOTION
# current_frame 213  status_motion  MOTION
# current_frame 214  status_motion  MOTION
# current_frame 215  status_motion  MOTION
# current_frame 216  status_motion  MOTION
# current_frame 217  status_motion  MOTION
# current_frame 218  status_motion  MOTION
# current_frame 219  status_motion  MOTION
# current_frame 220  status_motion  MOTION
# current_frame 221  status_motion  MOTION
# current_frame 222  status_motion  MOTION
# current_frame 223  status_motion  MOTION
# current_frame 224  status_motion  MOTION
# current_frame 225  status_motion  MOTION
# 226 211 15
# current_frame 226  status_motion  STOP
# current_frame 227  status_motion  STOP
# current_frame 228  status_motion  MOTION
# current_frame 229  status_motion  MOTION
# current_frame 230  status_motion  MOTION
# current_frame 231  status_motion  MOTION
# current_frame 232  status_motion  MOTION
# current_frame 233  status_motion  MOTION
# current_frame 234  status_motion  MOTION
# current_frame 235  status_motion  MOTION
# current_frame 236  status_motion  MOTION
# current_frame 237  status_motion  MOTION
# current_frame 238  status_motion  MOTION
# current_frame 239  status_motion  MOTION
# current_frame 240  status_motion  MOTION
# current_frame 241  status_motion  MOTION
# current_frame 242  status_motion  MOTION
# current_frame 243  status_motion  MOTION
# current_frame 244  status_motion  MOTION
# current_frame 245  status_motion  MOTION
# current_frame 246  status_motion  MOTION
# current_frame 247  status_motion  MOTION
# current_frame 248  status_motion  MOTION
# current_frame 249  status_motion  MOTION
# current_frame 250  status_motion  MOTION
# current_frame 251  status_motion  MOTION
# current_frame 252  status_motion  MOTION
# current_frame 253  status_motion  MOTION
# current_frame 254  status_motion  MOTION
# current_frame 255  status_motion  MOTION
# current_frame 256  status_motion  MOTION
# 257 228 29
# current_frame 257  status_motion  STOP
# current_frame 258  status_motion  STOP
# current_frame 259  status_motion  STOP
# current_frame 260  status_motion  MOTION
# current_frame 261  status_motion  MOTION
# current_frame 262  status_motion  MOTION
# current_frame 263  status_motion  MOTION
# current_frame 264  status_motion  MOTION
# current_frame 265  status_motion  MOTION
# current_frame 266  status_motion  MOTION
# current_frame 267  status_motion  MOTION
# current_frame 268  status_motion  MOTION
# current_frame 269  status_motion  MOTION
# current_frame 270  status_motion  MOTION
# current_frame 271  status_motion  MOTION
# current_frame 272  status_motion  MOTION
# current_frame 273  status_motion  MOTION
# current_frame 274  status_motion  MOTION
# current_frame 275  status_motion  MOTION
# current_frame 276  status_motion  MOTION
# current_frame 277  status_motion  MOTION
# current_frame 278  status_motion  MOTION
# current_frame 279  status_motion  MOTION
# current_frame 280  status_motion  MOTION
# current_frame 281  status_motion  MOTION
# current_frame 282  status_motion  MOTION
# current_frame 283  status_motion  MOTION
# current_frame 284  status_motion  MOTION
# current_frame 285  status_motion  MOTION
# current_frame 286  status_motion  MOTION
# current_frame 287  status_motion  MOTION
# current_frame 288  status_motion  MOTION
# current_frame 289  status_motion  MOTION
# current_frame 290  status_motion  MOTION
# current_frame 291  status_motion  MOTION
# current_frame 292  status_motion  MOTION
# current_frame 293  status_motion  MOTION
# current_frame 294  status_motion  MOTION
# current_frame 295  status_motion  MOTION
# current_frame 296  status_motion  MOTION
# current_frame 297  status_motion  MOTION
# current_frame 298  status_motion  MOTION
# current_frame 299  status_motion  MOTION
# current_frame 300  status_motion  MOTION
# current_frame 301  status_motion  MOTION
# current_frame 302  status_motion  MOTION
# current_frame 303  status_motion  MOTION
# current_frame 304  status_motion  MOTION
# current_frame 305  status_motion  MOTION
# current_frame 306  status_motion  MOTION
# current_frame 307  status_motion  MOTION
# current_frame 308  status_motion  MOTION
# current_frame 309  status_motion  MOTION
# current_frame 310  status_motion  MOTION
# current_frame 311  status_motion  MOTION
# current_frame 312  status_motion  MOTION
# current_frame 313  status_motion  MOTION
# current_frame 314  status_motion  MOTION
# current_frame 315  status_motion  MOTION
# current_frame 316  status_motion  MOTION
# current_frame 317  status_motion  MOTION
# current_frame 318  status_motion  MOTION
# current_frame 319  status_motion  MOTION
# current_frame 320  status_motion  MOTION
# current_frame 321  status_motion  MOTION
# current_frame 322  status_motion  MOTION
# current_frame 323  status_motion  MOTION
# current_frame 324  status_motion  MOTION
# current_frame 325  status_motion  MOTION
# current_frame 326  status_motion  MOTION
# current_frame 327  status_motion  MOTION
# current_frame 328  status_motion  MOTION
# current_frame 329  status_motion  MOTION
# current_frame 330  status_motion  MOTION
# current_frame 331  status_motion  MOTION
# current_frame 332  status_motion  MOTION
# current_frame 333  status_motion  MOTION
# current_frame 334  status_motion  MOTION
# current_frame 335  status_motion  MOTION
# current_frame 336  status_motion  MOTION
# current_frame 337  status_motion  MOTION
# 338 260 78
# current_frame 338  status_motion  STOP
# current_frame 339  status_motion  MOTION
# current_frame 340  status_motion  STOP
# current_frame 341  status_motion  MOTION
# current_frame 342  status_motion  MOTION
# current_frame 343  status_motion  MOTION
# current_frame 344  status_motion  STOP
# current_frame 345  status_motion  STOP
# current_frame 346  status_motion  MOTION
# current_frame 347  status_motion  STOP
# current_frame 348  status_motion  STOP
# current_frame 349  status_motion  STOP
# current_frame 350  status_motion  MOTION
# current_frame 351  status_motion  STOP
# current_frame 352  status_motion  MOTION
# current_frame 353  status_motion  MOTION
# current_frame 354  status_motion  MOTION
# current_frame 355  status_motion  MOTION
# current_frame 356  status_motion  STOP
# current_frame 357  status_motion  STOP
# current_frame 358  status_motion  STOP
# current_frame 359  status_motion  STOP
# current_frame 360  status_motion  STOP
# current_frame 361  status_motion  STOP
# current_frame 362  status_motion  STOP
# current_frame 363  status_motion  STOP
# current_frame 364  status_motion  STOP
# current_frame 365  status_motion  STOP
# current_frame 366  status_motion  STOP
# current_frame 367  status_motion  STOP
# current_frame 368  status_motion  STOP
# current_frame 369  status_motion  STOP
# current_frame 370  status_motion  STOP
# current_frame 371  status_motion  STOP
# current_frame 372  status_motion  STOP
# current_frame 373  status_motion  STOP
# current_frame 374  status_motion  STOP
# current_frame 375  status_motion  STOP
# current_frame 376  status_motion  STOP
# current_frame 377  status_motion  STOP
# current_frame 378  status_motion  STOP
# current_frame 379  status_motion  STOP
# current_frame 380  status_motion  STOP
# current_frame 381  status_motion  STOP
# current_frame 382  status_motion  STOP
# current_frame 383  status_motion  STOP
# current_frame 384  status_motion  STOP
# current_frame 385  status_motion  STOP
# current_frame 386  status_motion  STOP
# current_frame 387  status_motion  STOP
# current_frame 388  status_motion  STOP
# current_frame 389  status_motion  STOP
# current_frame 390  status_motion  STOP
# current_frame 391  status_motion  STOP
# 392 356 36
# current_frame 392  status_motion  MOTION
# current_frame 393  status_motion  MOTION
# current_frame 394  status_motion  MOTION
# current_frame 395  status_motion  MOTION
# current_frame 396  status_motion  MOTION
# current_frame 397  status_motion  MOTION
# current_frame 398  status_motion  MOTION
# current_frame 399  status_motion  MOTION
# current_frame 400  status_motion  MOTION
# current_frame 401  status_motion  MOTION
# current_frame 402  status_motion  MOTION
# current_frame 403  status_motion  MOTION
# current_frame 404  status_motion  MOTION
# current_frame 405  status_motion  MOTION
# current_frame 406  status_motion  MOTION
# current_frame 407  status_motion  MOTION
# current_frame 408  status_motion  MOTION
# current_frame 409  status_motion  MOTION
# current_frame 410  status_motion  MOTION
# current_frame 411  status_motion  MOTION
# current_frame 412  status_motion  MOTION
# current_frame 413  status_motion  MOTION
# current_frame 414  status_motion  MOTION
# current_frame 415  status_motion  MOTION
# current_frame 416  status_motion  MOTION
# current_frame 417  status_motion  MOTION
# current_frame 418  status_motion  MOTION
# current_frame 419  status_motion  MOTION
# current_frame 420  status_motion  MOTION
# current_frame 421  status_motion  MOTION
# current_frame 422  status_motion  MOTION
# current_frame 423  status_motion  MOTION
# current_frame 424  status_motion  MOTION
# current_frame 425  status_motion  MOTION
# current_frame 426  status_motion  MOTION
# current_frame 427  status_motion  MOTION
# current_frame 428  status_motion  MOTION
# current_frame 429  status_motion  MOTION
# current_frame 430  status_motion  MOTION
# 431 392 39
# current_frame 431  status_motion  STOP
# current_frame 432  status_motion  STOP
# current_frame 433  status_motion  STOP
# current_frame 434  status_motion  STOP
# current_frame 435  status_motion  STOP
# current_frame 436  status_motion  MOTION
# current_frame 437  status_motion  MOTION
# current_frame 438  status_motion  MOTION
# current_frame 439  status_motion  MOTION
# current_frame 440  status_motion  MOTION
# current_frame 441  status_motion  MOTION
# current_frame 442  status_motion  MOTION
# current_frame 443  status_motion  MOTION
# current_frame 444  status_motion  STOP
# current_frame 445  status_motion  MOTION
# current_frame 446  status_motion  MOTION
# current_frame 447  status_motion  MOTION
# current_frame 448  status_motion  STOP
# current_frame 449  status_motion  STOP
# current_frame 450  status_motion  STOP
# current_frame 451  status_motion  STOP
# current_frame 452  status_motion  STOP
# current_frame 453  status_motion  STOP
# current_frame 454  status_motion  STOP
# current_frame 455  status_motion  STOP
# current_frame 456  status_motion  MOTION
# current_frame 457  status_motion  MOTION
# current_frame 458  status_motion  STOP
# current_frame 459  status_motion  STOP
# current_frame 460  status_motion  STOP
# current_frame 461  status_motion  STOP
# current_frame 462  status_motion  STOP
# current_frame 463  status_motion  STOP
# current_frame 464  status_motion  STOP
# current_frame 465  status_motion  STOP
# current_frame 466  status_motion  STOP
# current_frame 467  status_motion  STOP
# current_frame 468  status_motion  MOTION
# current_frame 469  status_motion  MOTION
# current_frame 470  status_motion  MOTION
# current_frame 471  status_motion  STOP
# current_frame 472  status_motion  STOP
# current_frame 473  status_motion  STOP
# current_frame 474  status_motion  STOP
# current_frame 475  status_motion  MOTION
# current_frame 476  status_motion  MOTION
# current_frame 477  status_motion  MOTION
# current_frame 478  status_motion  MOTION
# current_frame 479  status_motion  MOTION
# current_frame 480  status_motion  MOTION
# current_frame 481  status_motion  MOTION
# current_frame 482  status_motion  STOP
# current_frame 483  status_motion  STOP
# current_frame 484  status_motion  STOP
# current_frame 485  status_motion  STOP
# current_frame 486  status_motion  MOTION
# current_frame 487  status_motion  MOTION
# current_frame 488  status_motion  MOTION
# current_frame 489  status_motion  MOTION
# current_frame 490  status_motion  MOTION
# current_frame 491  status_motion  MOTION
# current_frame 492  status_motion  MOTION
# current_frame 493  status_motion  MOTION
# current_frame 494  status_motion  MOTION
# current_frame 495  status_motion  MOTION
# current_frame 496  status_motion  MOTION
# current_frame 497  status_motion  MOTION
# current_frame 498  status_motion  MOTION
# current_frame 499  status_motion  MOTION
# current_frame 500  status_motion  MOTION
# current_frame 501  status_motion  MOTION
# current_frame 502  status_motion  MOTION
# current_frame 503  status_motion  MOTION
# current_frame 504  status_motion  MOTION
# current_frame 505  status_motion  MOTION
# current_frame 506  status_motion  MOTION
# current_frame 507  status_motion  MOTION
# current_frame 508  status_motion  MOTION
# current_frame 509  status_motion  MOTION
# current_frame 510  status_motion  MOTION
# 511 486 25
# current_frame 511  status_motion  STOP
# current_frame 512  status_motion  MOTION
# current_frame 513  status_motion  STOP
# current_frame 514  status_motion  MOTION
# current_frame 515  status_motion  MOTION
# current_frame 516  status_motion  STOP
# current_frame 517  status_motion  MOTION
# current_frame 518  status_motion  MOTION
# current_frame 519  status_motion  MOTION
# current_frame 520  status_motion  MOTION
# current_frame 521  status_motion  MOTION
# current_frame 522  status_motion  MOTION
# current_frame 523  status_motion  MOTION
# current_frame 524  status_motion  MOTION
# current_frame 525  status_motion  STOP
# current_frame 526  status_motion  MOTION
# current_frame 527  status_motion  MOTION
# current_frame 528  status_motion  MOTION
# current_frame 529  status_motion  MOTION
# current_frame 530  status_motion  MOTION
# current_frame 531  status_motion  MOTION
# current_frame 532  status_motion  MOTION
# current_frame 533  status_motion  MOTION
# current_frame 534  status_motion  MOTION
# current_frame 535  status_motion  MOTION
# current_frame 536  status_motion  MOTION
# current_frame 537  status_motion  MOTION
# current_frame 538  status_motion  MOTION
# current_frame 539  status_motion  MOTION
# current_frame 540  status_motion  MOTION
# current_frame 541  status_motion  MOTION
# current_frame 542  status_motion  MOTION
# current_frame 543  status_motion  MOTION
# current_frame 544  status_motion  MOTION
# current_frame 545  status_motion  MOTION
# current_frame 546  status_motion  MOTION
# current_frame 547  status_motion  MOTION
# current_frame 548  status_motion  MOTION
# current_frame 549  status_motion  MOTION
# current_frame 550  status_motion  MOTION
# current_frame 551  status_motion  MOTION
# current_frame 552  status_motion  MOTION
# current_frame 553  status_motion  MOTION
# current_frame 554  status_motion  MOTION
# current_frame 555  status_motion  MOTION
# current_frame 556  status_motion  MOTION
# current_frame 557  status_motion  MOTION
# current_frame 558  status_motion  MOTION
# current_frame 559  status_motion  MOTION
# current_frame 560  status_motion  MOTION
# current_frame 561  status_motion  MOTION
# current_frame 562  status_motion  MOTION
# current_frame 563  status_motion  MOTION
# current_frame 564  status_motion  MOTION
# current_frame 565  status_motion  MOTION
# current_frame 566  status_motion  MOTION
# current_frame 567  status_motion  MOTION
# current_frame 568  status_motion  MOTION
# current_frame 569  status_motion  MOTION
# current_frame 570  status_motion  MOTION
# current_frame 571  status_motion  MOTION
# current_frame 572  status_motion  MOTION
# current_frame 573  status_motion  MOTION
# current_frame 574  status_motion  MOTION
# current_frame 575  status_motion  MOTION
# current_frame 576  status_motion  MOTION
# current_frame 577  status_motion  MOTION
# current_frame 578  status_motion  MOTION
# current_frame 579  status_motion  MOTION
# current_frame 580  status_motion  MOTION
# current_frame 581  status_motion  MOTION
# 582 526 56
# current_frame 582  status_motion  STOP
# current_frame 583  status_motion  STOP
# current_frame 584  status_motion  MOTION
# current_frame 585  status_motion  MOTION
# current_frame 586  status_motion  STOP
# current_frame 587  status_motion  STOP
# current_frame 588  status_motion  STOP
# current_frame 589  status_motion  MOTION
# current_frame 590  status_motion  MOTION
# current_frame 591  status_motion  MOTION
# current_frame 592  status_motion  MOTION
# current_frame 593  status_motion  MOTION
# current_frame 594  status_motion  MOTION
# current_frame 595  status_motion  MOTION
# current_frame 596  status_motion  MOTION
# current_frame 597  status_motion  MOTION
# current_frame 598  status_motion  MOTION
# current_frame 599  status_motion  MOTION
# current_frame 600  status_motion  MOTION
# current_frame 601  status_motion  MOTION
# current_frame 602  status_motion  MOTION
# current_frame 603  status_motion  MOTION
# current_frame 604  status_motion  MOTION
# current_frame 605  status_motion  MOTION
# current_frame 606  status_motion  MOTION
# current_frame 607  status_motion  MOTION
# current_frame 608  status_motion  MOTION
# current_frame 609  status_motion  MOTION
# current_frame 610  status_motion  MOTION
# current_frame 611  status_motion  MOTION
# current_frame 612  status_motion  MOTION
# current_frame 613  status_motion  MOTION
# current_frame 614  status_motion  MOTION
# current_frame 615  status_motion  MOTION
# current_frame 616  status_motion  MOTION
# current_frame 617  status_motion  MOTION
# current_frame 618  status_motion  MOTION
# current_frame 619  status_motion  MOTION
# current_frame 620  status_motion  MOTION
# current_frame 621  status_motion  MOTION
# current_frame 622  status_motion  MOTION
# current_frame 623  status_motion  MOTION
# current_frame 624  status_motion  MOTION
# current_frame 625  status_motion  MOTION
# current_frame 626  status_motion  MOTION
# current_frame 627  status_motion  MOTION
# current_frame 628  status_motion  MOTION
# current_frame 629  status_motion  MOTION
# current_frame 630  status_motion  MOTION
# current_frame 631  status_motion  MOTION
# current_frame 632  status_motion  MOTION
# current_frame 633  status_motion  MOTION
# current_frame 634  status_motion  MOTION
# current_frame 635  status_motion  MOTION
# current_frame 636  status_motion  MOTION
# current_frame 637  status_motion  MOTION
# current_frame 638  status_motion  MOTION
# current_frame 639  status_motion  MOTION
# current_frame 640  status_motion  MOTION
# current_frame 641  status_motion  MOTION
# current_frame 642  status_motion  MOTION
# 643 589 54
# current_frame 643  status_motion  STOP
# current_frame 644  status_motion  MOTION
# current_frame 645  status_motion  MOTION
# current_frame 646  status_motion  MOTION
# current_frame 647  status_motion  MOTION
# current_frame 648  status_motion  MOTION
# current_frame 649  status_motion  MOTION
# current_frame 650  status_motion  MOTION
# current_frame 651  status_motion  MOTION
# current_frame 652  status_motion  MOTION
# current_frame 653  status_motion  MOTION
# current_frame 654  status_motion  MOTION
# current_frame 655  status_motion  MOTION
# current_frame 656  status_motion  MOTION
# current_frame 657  status_motion  MOTION
# current_frame 658  status_motion  MOTION
# current_frame 659  status_motion  MOTION
# current_frame 660  status_motion  MOTION
# current_frame 661  status_motion  MOTION
# current_frame 662  status_motion  MOTION
# current_frame 663  status_motion  MOTION
# current_frame 664  status_motion  MOTION
# current_frame 665  status_motion  MOTION
# current_frame 666  status_motion  MOTION
# current_frame 667  status_motion  MOTION
# current_frame 668  status_motion  MOTION
# current_frame 669  status_motion  MOTION
# current_frame 670  status_motion  MOTION
# current_frame 671  status_motion  MOTION
# current_frame 672  status_motion  MOTION
# current_frame 673  status_motion  MOTION
# current_frame 674  status_motion  MOTION
# current_frame 675  status_motion  MOTION
# current_frame 676  status_motion  MOTION
# current_frame 677  status_motion  MOTION
# current_frame 678  status_motion  MOTION
# current_frame 679  status_motion  MOTION
# current_frame 680  status_motion  MOTION
# current_frame 681  status_motion  MOTION
# current_frame 682  status_motion  MOTION
# current_frame 683  status_motion  MOTION
# current_frame 684  status_motion  MOTION
# 685 644 41
# current_frame 685  status_motion  STOP
# current_frame 686  status_motion  MOTION
# current_frame 687  status_motion  MOTION
# current_frame 688  status_motion  STOP
# current_frame 689  status_motion  MOTION
# current_frame 690  status_motion  STOP
# current_frame 691  status_motion  STOP
# current_frame 692  status_motion  MOTION
# current_frame 693  status_motion  MOTION
# current_frame 694  status_motion  MOTION
# current_frame 695  status_motion  MOTION
# current_frame 696  status_motion  MOTION
# current_frame 697  status_motion  MOTION
# current_frame 698  status_motion  MOTION
# current_frame 699  status_motion  MOTION
# current_frame 700  status_motion  MOTION
# current_frame 701  status_motion  MOTION
# current_frame 702  status_motion  MOTION
# current_frame 703  status_motion  MOTION
# current_frame 704  status_motion  MOTION
# current_frame 705  status_motion  MOTION
# current_frame 706  status_motion  MOTION
# current_frame 707  status_motion  MOTION
# current_frame 708  status_motion  MOTION
# current_frame 709  status_motion  MOTION
# current_frame 710  status_motion  MOTION
# current_frame 711  status_motion  MOTION
# current_frame 712  status_motion  MOTION
# current_frame 713  status_motion  MOTION
# current_frame 714  status_motion  MOTION
# current_frame 715  status_motion  MOTION
# current_frame 716  status_motion  MOTION
# current_frame 717  status_motion  MOTION
# current_frame 718  status_motion  MOTION
# current_frame 719  status_motion  MOTION
# current_frame 720  status_motion  MOTION
# current_frame 721  status_motion  MOTION
# current_frame 722  status_motion  MOTION
# current_frame 723  status_motion  MOTION
# current_frame 724  status_motion  MOTION
# current_frame 725  status_motion  MOTION
# current_frame 726  status_motion  MOTION
# current_frame 727  status_motion  MOTION
# current_frame 728  status_motion  MOTION
# current_frame 729  status_motion  MOTION
# current_frame 730  status_motion  MOTION
# current_frame 731  status_motion  MOTION
# current_frame 732  status_motion  MOTION
# 733 692 41
# current_frame 733  status_motion  STOP
# current_frame 734  status_motion  MOTION
# current_frame 735  status_motion  MOTION
# current_frame 736  status_motion  MOTION
# current_frame 737  status_motion  MOTION
# current_frame 738  status_motion  MOTION
# current_frame 739  status_motion  MOTION
# current_frame 740  status_motion  MOTION
# current_frame 741  status_motion  MOTION
# current_frame 742  status_motion  MOTION
# current_frame 743  status_motion  MOTION
# current_frame 744  status_motion  MOTION
# current_frame 745  status_motion  MOTION
# current_frame 746  status_motion  MOTION
# current_frame 747  status_motion  MOTION
# current_frame 748  status_motion  MOTION
# current_frame 749  status_motion  MOTION
# current_frame 750  status_motion  MOTION
# current_frame 751  status_motion  MOTION
# current_frame 752  status_motion  MOTION
# current_frame 753  status_motion  MOTION
# current_frame 754  status_motion  MOTION
# current_frame 755  status_motion  MOTION
# current_frame 756  status_motion  MOTION
# current_frame 757  status_motion  MOTION
# current_frame 758  status_motion  MOTION
# current_frame 759  status_motion  MOTION
# current_frame 760  status_motion  MOTION
# current_frame 761  status_motion  MOTION
# current_frame 762  status_motion  MOTION
# current_frame 763  status_motion  MOTION
# current_frame 764  status_motion  MOTION
# current_frame 765  status_motion  MOTION
# current_frame 766  status_motion  MOTION
# current_frame 767  status_motion  MOTION
# current_frame 768  status_motion  MOTION
# current_frame 769  status_motion  MOTION
# current_frame 770  status_motion  MOTION
# current_frame 771  status_motion  MOTION
# current_frame 772  status_motion  MOTION
# current_frame 773  status_motion  MOTION
# current_frame 774  status_motion  MOTION
# current_frame 775  status_motion  MOTION
# current_frame 776  status_motion  MOTION
# current_frame 777  status_motion  MOTION
# current_frame 778  status_motion  MOTION
# current_frame 779  status_motion  MOTION
# current_frame 780  status_motion  MOTION
# current_frame 781  status_motion  MOTION
# current_frame 782  status_motion  MOTION
# current_frame 783  status_motion  MOTION
# current_frame 784  status_motion  MOTION
# current_frame 785  status_motion  MOTION
# current_frame 786  status_motion  MOTION
# current_frame 787  status_motion  MOTION
# current_frame 788  status_motion  MOTION
# current_frame 789  status_motion  MOTION
# current_frame 790  status_motion  MOTION
# current_frame 791  status_motion  MOTION
# current_frame 792  status_motion  MOTION
# current_frame 793  status_motion  MOTION
# current_frame 794  status_motion  MOTION
# current_frame 795  status_motion  MOTION
# current_frame 796  status_motion  MOTION
# current_frame 797  status_motion  MOTION
# current_frame 798  status_motion  MOTION
# current_frame 799  status_motion  MOTION
# current_frame 800  status_motion  MOTION
# current_frame 801  status_motion  MOTION
# current_frame 802  status_motion  MOTION
# current_frame 803  status_motion  MOTION
# current_frame 804  status_motion  MOTION
# current_frame 805  status_motion  MOTION
# current_frame 806  status_motion  MOTION
# current_frame 807  status_motion  MOTION
# current_frame 808  status_motion  MOTION
# current_frame 809  status_motion  MOTION
# current_frame 810  status_motion  MOTION
# current_frame 811  status_motion  MOTION
# current_frame 812  status_motion  MOTION
# current_frame 813  status_motion  MOTION
# current_frame 814  status_motion  MOTION
# current_frame 815  status_motion  MOTION
# current_frame 816  status_motion  MOTION
# current_frame 817  status_motion  MOTION
# current_frame 818  status_motion  MOTION
# current_frame 819  status_motion  MOTION
# current_frame 820  status_motion  MOTION
# current_frame 821  status_motion  MOTION
# current_frame 822  status_motion  MOTION
# current_frame 823  status_motion  MOTION
# current_frame 824  status_motion  MOTION
# current_frame 825  status_motion  MOTION
# current_frame 826  status_motion  MOTION
# current_frame 827  status_motion  MOTION
# current_frame 828  status_motion  MOTION
# current_frame 829  status_motion  MOTION
# current_frame 830  status_motion  MOTION
# current_frame 831  status_motion  MOTION
# current_frame 832  status_motion  MOTION
# current_frame 833  status_motion  MOTION
# current_frame 834  status_motion  MOTION
# current_frame 835  status_motion  MOTION
# current_frame 836  status_motion  MOTION
# current_frame 837  status_motion  MOTION
# current_frame 838  status_motion  MOTION
# current_frame 839  status_motion  MOTION
# current_frame 840  status_motion  MOTION
# current_frame 841  status_motion  MOTION
# current_frame 842  status_motion  MOTION
# current_frame 843  status_motion  MOTION
# current_frame 844  status_motion  MOTION
# current_frame 845  status_motion  MOTION
# 846 734 112
# current_frame 846  status_motion  STOP
# current_frame 847  status_motion  STOP
# current_frame 848  status_motion  MOTION
# current_frame 849  status_motion  STOP
# current_frame 850  status_motion  STOP
# current_frame 851  status_motion  MOTION
# current_frame 852  status_motion  STOP
# current_frame 853  status_motion  STOP
# current_frame 854  status_motion  MOTION
# current_frame 855  status_motion  STOP
# current_frame 856  status_motion  STOP
# current_frame 857  status_motion  STOP
# current_frame 858  status_motion  STOP
# current_frame 859  status_motion  STOP
# current_frame 860  status_motion  STOP
# current_frame 861  status_motion  STOP
# current_frame 862  status_motion  STOP
# current_frame 863  status_motion  STOP
# current_frame 864  status_motion  STOP
# current_frame 865  status_motion  STOP
# current_frame 866  status_motion  STOP
# current_frame 867  status_motion  STOP
# current_frame 868  status_motion  STOP
# current_frame 869  status_motion  STOP
# current_frame 870  status_motion  STOP
# current_frame 871  status_motion  STOP
# current_frame 872  status_motion  STOP
# current_frame 873  status_motion  STOP
# current_frame 874  status_motion  STOP
# current_frame 875  status_motion  STOP
# current_frame 876  status_motion  STOP
# current_frame 877  status_motion  STOP
# current_frame 878  status_motion  STOP
# current_frame 879  status_motion  STOP
# current_frame 880  status_motion  STOP
# current_frame 881  status_motion  STOP
# current_frame 882  status_motion  STOP
# current_frame 883  status_motion  STOP
# current_frame 884  status_motion  STOP
# current_frame 885  status_motion  STOP
# current_frame 886  status_motion  STOP
# current_frame 887  status_motion  STOP
# current_frame 888  status_motion  STOP
# current_frame 889  status_motion  STOP
# current_frame 890  status_motion  STOP
# current_frame 891  status_motion  STOP
# current_frame 892  status_motion  STOP
# current_frame 893  status_motion  STOP
# current_frame 894  status_motion  STOP
# current_frame 895  status_motion  STOP
# current_frame 896  status_motion  STOP
# current_frame 897  status_motion  STOP
# current_frame 898  status_motion  STOP
# current_frame 899  status_motion  STOP
# current_frame 900  status_motion  STOP
# current_frame 901  status_motion  STOP
# current_frame 902  status_motion  STOP
# current_frame 903  status_motion  STOP
# current_frame 904  status_motion  STOP
# current_frame 905  status_motion  STOP
# current_frame 906  status_motion  STOP
# current_frame 907  status_motion  STOP
# current_frame 908  status_motion  STOP
# current_frame 909  status_motion  STOP
# current_frame 910  status_motion  STOP
# current_frame 911  status_motion  STOP
# current_frame 912  status_motion  STOP
# current_frame 913  status_motion  STOP
# current_frame 914  status_motion  STOP
# current_frame 915  status_motion  STOP
# current_frame 916  status_motion  STOP
# current_frame 917  status_motion  STOP
# current_frame 918  status_motion  STOP
# current_frame 919  status_motion  STOP
# current_frame 920  status_motion  STOP
# current_frame 921  status_motion  STOP
# current_frame 922  status_motion  STOP

# %%
import time
a=time.time()
time.sleep(2.4)
b=time.time()
b-a

# %%
print(dir(datetime))
